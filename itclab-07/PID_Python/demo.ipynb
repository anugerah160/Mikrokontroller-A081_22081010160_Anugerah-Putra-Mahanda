# %%
import control_demo as cd
run_control = cd.GUI()
# Out:
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\ipywidgets\widgets\widget.py:676, in Widget._handle_msg(self, msg)
#     674         if 'buffer_paths' in data:
#     675             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 676         self.set_state(state)
#     678 # Handle a state request.
#     679 elif method == 'request_state':
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\ipywidgets\widgets\widget.py:545, in Widget.set_state(self, sync_data)
#     542 if name in self.keys:
#     543     from_json = self.trait_metadata(name, 'from_json',
#     544                                     self._trait_from_json)
# --> 545     self.set_trait(name, from_json(sync_data[name], self))
#
# ...

# %%
run_control.app()
# Out:
# ...
# e:\Kuliah\Semester 5\micro1\Mikrokontroller-A081_22081010160_Anugerah-Putra-Mahanda\itclab-07\PID_Python\control_demo.py:1150: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   y = odeint(self._heater, Th0, ts, args=(Q10, Q20))
# e:\Kuliah\Semester 5\micro1\Mikrokontroller-A081_22081010160_Anugerah-Putra-Mahanda\itclab-07\PID_Python\control_demo.py:1232: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   y = odeint(self._heater, Th0, ts, args=(Q10, Q20))
# e:\Kuliah\Semester 5\micro1\Mikrokontroller-A081_22081010160_Anugerah-Putra-Mahanda\itclab-07\PID_Python\control_demo.py:1392: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   y = odeint(self._heater, Th0, ts, args=(Q10, Q20))

# %%
run_control.config()
